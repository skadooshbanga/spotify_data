# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("songs_normalize.csv")

# %%
data.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# ...

# %%
data.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667437     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512435     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# ...

# %%
data.dtypes
# Out:
# artist               object
# song                 object
# duration_ms           int64
# explicit               bool
# year                  int64
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# genre                object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              2000 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
# ...

# %%
data[["artist","song","popularity","danceability"]].sort_values(["danceability"], ascending=False ).head()
# Out:
#                  artist                        song  popularity  danceability
# 714           Timbaland               Give It To Me          70         0.975
# 425               Kelis                    Trick Me          63         0.970
# 225       Missy Elliott     4 My People (feat. Eve)          49         0.969
# 602   Justin Timberlake  SexyBack (feat. Timbaland)          78         0.967
# 1428        Nicki Minaj                    Anaconda          66         0.964

# %%
data.shape
# Out:
# (2000, 18)

# %%
data.isna().sum() #our data is alrady cleaned from Nan values, we don't need to clean this dataset again
# Out:
# artist              0
# song                0
# duration_ms         0
# explicit            0
# year                0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# genre               0
# dtype: int64

# %%
fastest_eminem = data[(data["artist"]== "Eminem")&(data["tempo"] > 130)]
not_too_emo = fastest_eminem["valence"]

# %%
print(fastest_eminem["genre"].value_counts(),"\nis it live in your blood %:", 100*fastest_eminem["liveness"].mean())
# Out:
# hip hop    5
# Name: genre, dtype: int64
# is it live in your blood %: 14.350000000000001

# %%
data["genre"].value_counts().tail()
# Out:
# easy listening                      1
# country, latin                      1
# hip hop, latin, Dance/Electronic    1
# rock, Folk/Acoustic, pop            1
# Folk/Acoustic, rock                 1
# Name: genre, dtype: int64

# %%
rock_n_metal = data[data["genre"].isin(["rock", "metal"])].sort_values("liveness", ascending=False)

# %%
data[(data["genre"]== "metal")]["genre"].value_counts()
# Out:
# metal    9
# Name: genre, dtype: int64

# %%
rnm_energy = rock_n_metal.sort_values("energy", ascending=False)
artist_energy= rnm_energy[["artist","song","popularity","energy"]]
artist_energy
# Out:
#                      artist                 song  popularity  energy
# 472               Green Day       American Idiot          77   0.988
# 579           Kaiser Chiefs     I Predict A Riot          63   0.979
# 740          Arctic Monkeys           Brianstorm          67   0.974
# 280   Red Hot Chili Peppers           By the Way          73   0.970
# 654            Fall Out Boy         Dance, Dance          74   0.961
# ...                     ...                  ...         ...     ...
# 675          The Raconteurs  Steady, As She Goes          56   0.578
# 1344         Arctic Monkeys     Do I Wanna Know?          84   0.532
# 345             Limp Bizkit     Behind Blue Eyes          70   0.489
# 1619      Twenty One Pilots             Heathens          80   0.396
# 466             Evanescence          My Immortal          72   0.265
#
# [67 rows x 4 columns]

# %%
fig = sns.relplot(y= artist_energy["artist"], x=artist_energy["energy"],hue=artist_energy["artist"], size=artist_energy["popularity"])
fig._legend.remove()
plt.figure(figsize=(5,15))
